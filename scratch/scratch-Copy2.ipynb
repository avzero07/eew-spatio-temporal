# %%
import torch
import torch.nn as nn
from est_lib.util.obspy_util import *
from est_lib.dataset.seismic_dataset import CNDataset
from obspy import UTCDateTime as dt
from torch.utils.data import DataLoader

# %%
from torch_geometric_temporal.nn.attention import MTGNN

# %%
import os
from tqdm.notebook import tqdm

# %%
# Env Stuff
inv_file_name = 'inv.xml'
str_file_name = 'str.pkl'
file_path = os.path.abspath('../est_lib/_data/')
sta_list = ['HOLB','BFSB','CBB']

def check_files():
    contents = os.listdir(file_path)
    if inv_file_name not in contents:
        inv = inventory_retriever(network="CN",
                              sta_list=sta_list,
                              level='response')
        # Save File
        f_path = os.path.join(file_path,inv_file_name)
        op_file_path = inventory_writer(inv,
                                    f_path,
                                    file_format="STATIONXML")
    if str_file_name not in contents:
        stream = stream_retriever(event_time = dt('2019-12-25T03:36:01.578000Z'),
                              seconds_before = 600,
                              seconds_after = 1500,
                              network="CN",
                              sta_list=sta_list,
                              channel_list=['HHE'])
        f_path = os.path.join(file_path,str_file_name)
        op_file_path = stream_writer(stream,
                                 f_path,
                                 file_format="PICKLE")
    print(file_path)
    print(os.listdir(file_path))

# %%
# Retrieve Stream and Inventory
check_files()
# Out:
# C:\Users\aksha\Desktop\eew-spatio-temporal\est_lib\_data
# ['inv.xml', 'str.pkl']

# %%
# Set Up Dataset Object
obj = CNDataset(os.path.join(file_path,inv_file_name),
                os.path.join(file_path,str_file_name),
                    sta_list=sta_list,
                    ip_dim=1,
                    num_nodes=3,
                    seq_length=101) # Logical Bug with length

# %%
# View Streams
op = obj.stream.plot()

# %%
print(obj.stream)
# Out:
# 3 Trace(s) in Stream:
# CN.BFSB..HHE | 2019-12-25T03:26:01.580000Z - 2019-12-25T03:51:01.570000Z | 100.0 Hz, 150000 samples
# CN.CBB..HHE  | 2019-12-25T03:26:01.580000Z - 2019-12-25T03:51:01.570000Z | 100.0 Hz, 150000 samples
# CN.HOLB..HHE | 2019-12-25T03:26:01.580000Z - 2019-12-25T03:51:01.570000Z | 100.0 Hz, 150000 samples

# %%
from est_lib.util.obspy_plot import ray_plot
import numpy as np
# Plot
lat = 50.6081
lon = -129.9656
ray_plot(
    ev_lat=lat,
    ev_lon=lon,
    min_lat=47.8,
    max_lat=52.,
    min_lon=-130.5,
    max_lon=-121,
    streams=obj.stream,
    inventory=obj.inv)

# %%
# Set Up Dataloader
proto_batch_size = 20
train_loader = DataLoader(obj,batch_size=proto_batch_size,shuffle=False)

# %%
'''
#feat, lab = next(iter(train_loader))
print(feat.shape)
print(lab.shape)
'''
# Out:
# '\n#feat, lab = next(iter(train_loader))\nprint(feat.shape)\nprint(lab.shape)\n'

# %%
# Set Up CUDA
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"
    
obj.data = obj.data.to(device)
obj.labels = obj.labels.to(device)

# %%
print(obj.data.device)
print(obj.labels.device)
# Out:
# cuda:0
# cuda:0

# %%
# Set Up Model
gcn_true = True
build_adj = True
dropout = 0.3
subgraph_size = 3
gcn_depth = 2
num_nodes = obj.num_nodes # Important
node_dim = 1 # Need to verify from Paper
dilation_exponential = 1
conv_channels = 32
residual_channels = 32
skip_channels = 64
end_channels = 128
in_dim = obj.ip_dim # Important
seq_in_len = obj.seq_length-1 # Important # seq-len bug to be adressed
seq_out_len = 1
layers = 3
batch_size = proto_batch_size # Set by Data Loader
propalpha = 0.05
tanhalpha = 3
num_split = 1
kernel_size = 7
kernel_set = [2, 3, 6, 7]

# %%
model = MTGNN(gcn_true=gcn_true, build_adj=build_adj, gcn_depth=gcn_depth, num_nodes=num_nodes,
                kernel_size=kernel_size, kernel_set=kernel_set, dropout=dropout, subgraph_size=subgraph_size,
                node_dim=node_dim, dilation_exponential=dilation_exponential,
                conv_channels=conv_channels, residual_channels=residual_channels,
                skip_channels=skip_channels, end_channels=end_channels,
                seq_length=seq_in_len, in_dim=in_dim, out_dim=seq_out_len,
                layers=layers, propalpha=propalpha, tanhalpha=tanhalpha, layer_norm_affline=True)
#model.double()
model.to(device)
# Out:
# MTGNN(
#   (_mtgnn_layers): ModuleList(
#     (0): MTGNNLayer(
#       (_filter_conv): DilatedInception(
#         (_time_conv): ModuleList(
#           (0): Conv2d(32, 8, kernel_size=(1, 2), stride=(1, 1))
#           (1): Conv2d(32, 8, kernel_size=(1, 3), stride=(1, 1))
#           (2): Conv2d(32, 8, kernel_size=(1, 6), stride=(1, 1))
#           (3): Conv2d(32, 8, kernel_size=(1, 7), stride=(1, 1))
#         )
#       )
#       (_gate_conv): DilatedInception(
#         (_time_conv): ModuleList(
#           (0): Conv2d(32, 8, kernel_size=(1, 2), stride=(1, 1))
#           (1): Conv2d(32, 8, kernel_size=(1, 3), stride=(1, 1))
#           (2): Conv2d(32, 8, kernel_size=(1, 6), stride=(1, 1))
#           (3): Conv2d(32, 8, kernel_size=(1, 7), stride=(1, 1))
#         )
#       )
#       (_residual_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (_skip_conv): Conv2d(32, 64, kernel_size=(1, 94), stride=(1, 1))
#       (_mixprop_conv1): MixProp(
#         (_mlp): Linear(
#           (_mlp): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (_mixprop_conv2): MixProp(
#         (_mlp): Linear(
#           (_mlp): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (_normalization): LayerNormalization()
#     )
#     (1): MTGNNLayer(
#       (_filter_conv): DilatedInception(
#         (_time_conv): ModuleList(
#           (0): Conv2d(32, 8, kernel_size=(1, 2), stride=(1, 1))
#           (1): Conv2d(32, 8, kernel_size=(1, 3), stride=(1, 1))
#           (2): Conv2d(32, 8, kernel_size=(1, 6), stride=(1, 1))
#           (3): Conv2d(32, 8, kernel_size=(1, 7), stride=(1, 1))
#         )
#       )
#       (_gate_conv): DilatedInception(
#         (_time_conv): ModuleList(
#           (0): Conv2d(32, 8, kernel_size=(1, 2), stride=(1, 1))
#           (1): Conv2d(32, 8, kernel_size=(1, 3), stride=(1, 1))
#           (2): Conv2d(32, 8, kernel_size=(1, 6), stride=(1, 1))
#           (3): Conv2d(32, 8, kernel_size=(1, 7), stride=(1, 1))
#         )
#       )
#       (_residual_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (_skip_conv): Conv2d(32, 64, kernel_size=(1, 88), stride=(1, 1))
#       (_mixprop_conv1): MixProp(
#         (_mlp): Linear(
#           (_mlp): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (_mixprop_conv2): MixProp(
#         (_mlp): Linear(
#           (_mlp): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (_normalization): LayerNormalization()
#     )
#     (2): MTGNNLayer(
#       (_filter_conv): DilatedInception(
#         (_time_conv): ModuleList(
#           (0): Conv2d(32, 8, kernel_size=(1, 2), stride=(1, 1))
#           (1): Conv2d(32, 8, kernel_size=(1, 3), stride=(1, 1))
#           (2): Conv2d(32, 8, kernel_size=(1, 6), stride=(1, 1))
#           (3): Conv2d(32, 8, kernel_size=(1, 7), stride=(1, 1))
#         )
#       )
#       (_gate_conv): DilatedInception(
#         (_time_conv): ModuleList(
#           (0): Conv2d(32, 8, kernel_size=(1, 2), stride=(1, 1))
#           (1): Conv2d(32, 8, kernel_size=(1, 3), stride=(1, 1))
#           (2): Conv2d(32, 8, kernel_size=(1, 6), stride=(1, 1))
#           (3): Conv2d(32, 8, kernel_size=(1, 7), stride=(1, 1))
#         )
#       )
#       (_residual_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (_skip_conv): Conv2d(32, 64, kernel_size=(1, 82), stride=(1, 1))
#       (_mixprop_conv1): MixProp(
#         (_mlp): Linear(
#           (_mlp): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (_mixprop_conv2): MixProp(
#         (_mlp): Linear(
#           (_mlp): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (_normalization): LayerNormalization()
#     )
#   )
#   (_graph_constructor): GraphConstructor(
#     (_embedding1): Embedding(3, 1)
#     (_embedding2): Embedding(3, 1)
#     (_linear1): Linear(in_features=1, out_features=1, bias=True)
#     (_linear2): Linear(in_features=1, out_features=1, bias=True)
#   )
#   (_start_conv): Conv2d(1, 32, kernel_size=(1, 1), stride=(1, 1))
#   (_skip_conv_0): Conv2d(1, 64, kernel_size=(1, 100), stride=(1, 1))
#   (_skip_conv_E): Conv2d(32, 64, kernel_size=(1, 82), stride=(1, 1))
#   (_end_conv_1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#   (_end_conv_2): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
# Train Param
criterion = nn.MSELoss(size_average=False)
evaluateL2 = nn.MSELoss(size_average=False)
evaluateL1 = nn.L1Loss(size_average=False)
optimizer = torch.optim.Adam(model.parameters(),lr=0.01)
# Out:
# D:\Development\Anaconda\envs\torch-spatio-temporal\lib\site-packages\torch\nn\_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))

# %%
# Train Loop
losses = list()
epochs = 1
model.train() # Train Mode
for e in tqdm(range(epochs)):
    for bid, samp in tqdm(enumerate(train_loader)):
        model.zero_grad()
#        if bid == 1:
#           break
        x = samp[0]
        y = torch.unsqueeze(samp[1],3) # or squeeze op
        # cuda stuff goes here
        op = model(x.float())
        loss = criterion(op,y.float())
        losses.append(loss.item())
        loss.backward()
        optimizer.step()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
print(losses)
# Out:
# [1906.9068603515625, 515798.6875, 598.26123046875, 9101.384765625, 2955.7802734375, 319.29376220703125, 37.972721099853516, 48.61962127685547, 3154.08056640625, 0.141734778881073, 7.974997520446777, 24.093059539794922, 34.67291259765625, 25.644031524658203, 6.597207546234131, 2.0860280990600586, 21.94798469543457, 30.758277893066406, 10.95601749420166, 0.612724781036377, 17.858802795410156, 22.726118087768555, 4.24188232421875, 4.001913070678711, 18.23775863647461, 9.087007522583008, 0.2971634566783905, 11.543172836303711, 9.980149269104004, 0.028881605714559555, 7.657018184661865, 8.375652313232422, 0.05474823713302612, 5.974964618682861, 6.085014343261719, 1.1150370482937433e-05, 5.109124660491943, 3.6875510215759277, 0.1776854246854782, 4.323040962219238, 1.4238975048065186, 1.0256450176239014, 3.3091230392456055, 0.12416835129261017, 1.9982402324676514, 1.6658872365951538, 0.20616574585437775, 2.148355484008789, 0.242766872048378, 1.055711269378662, 1.157759428024292, 0.09752552211284637, 1.3377845287322998, 0.12564519047737122, 0.7445910573005676, 0.602114200592041, 0.15710243582725525, 0.8077929019927979, 0.005402696784585714, 0.6140830516815186, 0.1769188940525055, 0.26945245265960693, 0.3692428469657898, 0.04730977490544319, 0.4020678997039795, 0.003969775978475809, 0.3100115656852722, 0.06871919333934784, 0.16718366742134094, 0.1458950936794281, 0.05740012973546982, 0.1821591556072235, 0.007480919826775789, 0.1729910522699356, 0.0010268623009324074, 0.13099628686904907, 0.015496275387704372, 0.0882740467786789, 0.033557865768671036, 0.05081308260560036, 0.04636375978589058, 0.025264069437980652, 0.05128882825374603, 0.010478337295353413, 0.0492154061794281, 0.0029832390137016773, 0.0445052832365036, 0.0004110936133656651, 0.03702608495950699, 0.00016683165449649096, 0.029698124155402184, 0.0007451614364981651, 0.0230395644903183, 0.0014730705879628658, 0.01842741295695305, 0.0017148752231150866, 0.014419869519770145, 0.0018942297901958227, 0.012192880734801292, 0.001373071689158678, 0.009050296619534492, 0.0011475823121145368, 0.006909891031682491, 0.0011749211698770523, 0.006695873104035854, 0.0006645659450441599, 0.005536263808608055, 0.0005368274869397283, 0.005348729435354471, 0.00021448198822326958, 0.0045211766846477985, 9.486365888733417e-05, 0.0036581652238965034, 9.939503797795624e-05, 0.0030989767983555794, 0.0002611438976600766, 0.00251864199526608, 0.000569357187487185, 0.0016489485278725624, 0.0008345310925506055, 0.0011826081899926066, 0.0012369195464998484, 0.0004895022138953209, 0.0011338302865624428, 0.00026833685114979744, 0.0010803255718201399, 0.00019017586600966752, 0.001246766303665936, 0.00010096208279719576, 0.0009799846448004246, 0.00022511159477289766, 0.000627527479082346, 0.000382239930331707, 0.0002831691817846149, 0.0003864860627800226, 0.000142756849527359, 0.00028311103233136237, 7.795388955855742e-05, 0.00017106335144490004, 7.55998189561069e-05, 0.00022485246881842613, 7.804530469002202e-05, 0.0001419128238921985, 8.641244494356215e-05, 0.00011004840780515224, 7.995486521394923e-05, 0.00013348436914384365, 8.02900904091075e-05, 0.00014284919598139822, 0.00011228626681258902, 7.461034692823887e-05, 0.0001160797692136839, 0.00010105832188855857, 0.00015069385699462146, 0.00011535493831615895, 0.00016370075172744691, 0.0001111479286919348, 0.00015307578723877668, 0.00016982259694486856, 0.00012372102355584502, 0.0002058637619484216, 9.60835168370977e-05, 0.00023110512120183557, 0.00018474747776053846, 8.871092722984031e-05, 0.00020967228920198977, 0.00010828538506757468, 0.00012776456424035132, 0.00013031148409936577, 7.30939136701636e-05, 0.00019946254906244576, 0.0001035454188240692, 0.00011441366950748488, 0.0002151662192773074, 0.00013142992975190282, 0.00015496194828301668, 0.00017598368867766112, 0.00011153468221891671, 0.0003815755480900407, 0.00022463215282186866, 0.00013772929378319532, 0.00038003420922905207, 0.00016698006947990507, 0.00014329986879602075, 0.0002010700263781473 ...

# %%
len(losses)
# Out:
# 7495

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(losses)
plt.yscale('log')
plt.grid()
plt.xlabel("Batch Number")
plt.ylabel("Mean Squared Error of Prediction")
plt.title("Error Over Epoch 1")
plt.show()

# %%
adj = model._graph_constructor(model._idx.to(device)).detach().cpu().numpy()
print(adj)
# Out:
# [[ 0.          0.91787964  0.8494307 ]
#  [ 0.          0.          0.88466084]
#  [ 0.          0.          0.        ]]

# %%
# Eval Loop
test_loader = DataLoader(obj,batch_size=40,shuffle=False)
loss_eval = list()
op_eval = list()
model.eval()
for e in tqdm(range(epochs)):
    for bid, samp in tqdm(enumerate(test_loader)):
#        if bid == 1:
#           break
        x = samp[0]
        # cuda stuff goes here
        op = model(x.float())
        op_eval.append(op.detach().cpu())
        y = torch.unsqueeze(samp[1],3) # or squeeze op
        loss = criterion(op,y.float())
        loss_eval.append(loss.item())
        del loss
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
type(adj)
# Out:
# numpy.ndarray

# %%
from est_lib.util.obspy_plot import adj_plot
adj_plot(
    min_lat=47.8,
    max_lat=52.,
    min_lon=-130.5,
    max_lon=-121,
    streams=obj.stream,
    inventory=obj.inv,
    adj_mat=adj)
