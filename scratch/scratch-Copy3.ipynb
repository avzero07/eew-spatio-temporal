# %%
import torch
import torch.nn as nn
from est_lib.util.obspy_util import *
from est_lib.dataset.seismic_dataset import CNDataset
from obspy import UTCDateTime as dt
from torch.utils.data import DataLoader

# %%
from torch_geometric_temporal.nn.attention import MTGNN

# %%
import os
from tqdm.notebook import tqdm

# %%
# Env Stuff
inv_file_name = 'inv.xml'
str_file_name = 'str.pkl'
file_path = os.path.abspath('../est_lib/_data/alter/')
sta_list = ['HOLB','BFSB','CBB']

def check_files():
    contents = os.listdir(file_path)
    if inv_file_name not in contents:
        inv = inventory_retriever(network="CN",
                              sta_list=sta_list,
                              level='response')
        # Save File
        f_path = os.path.join(file_path,inv_file_name)
        op_file_path = inventory_writer(inv,
                                    f_path,
                                    file_format="STATIONXML")
    if str_file_name not in contents:
        stream = stream_retriever(event_time = dt('2021-05-27T17:56'),
                              seconds_before = 600,
                              seconds_after = 1500,
                              network="CN",
                              sta_list=sta_list,
                              channel_list=['HHE'])
        f_path = os.path.join(file_path,str_file_name)
        op_file_path = stream_writer(stream,
                                 f_path,
                                 file_format="PICKLE")
    print(file_path)
    print(os.listdir(file_path))

# %%
# Retrieve Stream and Inventory
check_files()
# Out:
# C:\Users\aksha\Desktop\eew-spatio-temporal\est_lib\_data\alter
# ['inv.xml', 'str.pkl']

# %%
# Set Up Dataset Object
obj = CNDataset(os.path.join(file_path,inv_file_name),
                os.path.join(file_path,str_file_name),
                    sta_list=sta_list,
                    ip_dim=1,
                    num_nodes=3,
                    seq_length=101) # Logical Bug with length

# %%
# View Streams
op = obj.stream.plot()

# %%
print(obj.stream)
# Out:
# 3 Trace(s) in Stream:
# CN.BFSB..HHE | 2021-05-27T17:46:00.000000Z - 2021-05-27T18:11:00.000000Z | 100.0 Hz, 150001 samples
# CN.CBB..HHE  | 2021-05-27T17:46:00.000000Z - 2021-05-27T18:11:00.000000Z | 100.0 Hz, 150001 samples
# CN.HOLB..HHE | 2021-05-27T17:46:00.000000Z - 2021-05-27T18:11:00.000000Z | 100.0 Hz, 150001 samples

# %%
from est_lib.util.obspy_plot import ray_plot
import numpy as np
# Plot
lat = 50.6081
lon = -129.9656
ray_plot(
    ev_lat=lat,
    ev_lon=lon,
    min_lat=47.8,
    max_lat=52.,
    min_lon=-130.5,
    max_lon=-121,
    streams=obj.stream,
    inventory=obj.inv)

# %%
# Set Up Dataloader
proto_batch_size = 20
train_loader = DataLoader(obj,batch_size=proto_batch_size,shuffle=False)

# %%
'''
#feat, lab = next(iter(train_loader))
print(feat.shape)
print(lab.shape)
'''
# Out:
# '\n#feat, lab = next(iter(train_loader))\nprint(feat.shape)\nprint(lab.shape)\n'

# %%
# Set Up CUDA
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"
    
obj.data = obj.data.to(device)
obj.labels = obj.labels.to(device)

# %%
print(obj.data.device)
print(obj.labels.device)
# Out:
# cuda:0
# cuda:0

# %%
# Set Up Model
gcn_true = True
build_adj = True
dropout = 0.3
subgraph_size = 3
gcn_depth = 2
num_nodes = obj.num_nodes # Important
node_dim = 1 # Need to verify from Paper
dilation_exponential = 1
conv_channels = 32
residual_channels = 32
skip_channels = 64
end_channels = 128
in_dim = obj.ip_dim # Important
seq_in_len = obj.seq_length-1 # Important # seq-len bug to be adressed
seq_out_len = 1
layers = 3
batch_size = proto_batch_size # Set by Data Loader
propalpha = 0.05
tanhalpha = 3
num_split = 1
kernel_size = 7
kernel_set = [2, 3, 6, 7]

# %%
model = MTGNN(gcn_true=gcn_true, build_adj=build_adj, gcn_depth=gcn_depth, num_nodes=num_nodes,
                kernel_size=kernel_size, kernel_set=kernel_set, dropout=dropout, subgraph_size=subgraph_size,
                node_dim=node_dim, dilation_exponential=dilation_exponential,
                conv_channels=conv_channels, residual_channels=residual_channels,
                skip_channels=skip_channels, end_channels=end_channels,
                seq_length=seq_in_len, in_dim=in_dim, out_dim=seq_out_len,
                layers=layers, propalpha=propalpha, tanhalpha=tanhalpha, layer_norm_affline=True)
#model.double()
model.to(device)
# Out:
# MTGNN(
#   (_mtgnn_layers): ModuleList(
#     (0): MTGNNLayer(
#       (_filter_conv): DilatedInception(
#         (_time_conv): ModuleList(
#           (0): Conv2d(32, 8, kernel_size=(1, 2), stride=(1, 1))
#           (1): Conv2d(32, 8, kernel_size=(1, 3), stride=(1, 1))
#           (2): Conv2d(32, 8, kernel_size=(1, 6), stride=(1, 1))
#           (3): Conv2d(32, 8, kernel_size=(1, 7), stride=(1, 1))
#         )
#       )
#       (_gate_conv): DilatedInception(
#         (_time_conv): ModuleList(
#           (0): Conv2d(32, 8, kernel_size=(1, 2), stride=(1, 1))
#           (1): Conv2d(32, 8, kernel_size=(1, 3), stride=(1, 1))
#           (2): Conv2d(32, 8, kernel_size=(1, 6), stride=(1, 1))
#           (3): Conv2d(32, 8, kernel_size=(1, 7), stride=(1, 1))
#         )
#       )
#       (_residual_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (_skip_conv): Conv2d(32, 64, kernel_size=(1, 94), stride=(1, 1))
#       (_mixprop_conv1): MixProp(
#         (_mlp): Linear(
#           (_mlp): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (_mixprop_conv2): MixProp(
#         (_mlp): Linear(
#           (_mlp): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (_normalization): LayerNormalization()
#     )
#     (1): MTGNNLayer(
#       (_filter_conv): DilatedInception(
#         (_time_conv): ModuleList(
#           (0): Conv2d(32, 8, kernel_size=(1, 2), stride=(1, 1))
#           (1): Conv2d(32, 8, kernel_size=(1, 3), stride=(1, 1))
#           (2): Conv2d(32, 8, kernel_size=(1, 6), stride=(1, 1))
#           (3): Conv2d(32, 8, kernel_size=(1, 7), stride=(1, 1))
#         )
#       )
#       (_gate_conv): DilatedInception(
#         (_time_conv): ModuleList(
#           (0): Conv2d(32, 8, kernel_size=(1, 2), stride=(1, 1))
#           (1): Conv2d(32, 8, kernel_size=(1, 3), stride=(1, 1))
#           (2): Conv2d(32, 8, kernel_size=(1, 6), stride=(1, 1))
#           (3): Conv2d(32, 8, kernel_size=(1, 7), stride=(1, 1))
#         )
#       )
#       (_residual_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (_skip_conv): Conv2d(32, 64, kernel_size=(1, 88), stride=(1, 1))
#       (_mixprop_conv1): MixProp(
#         (_mlp): Linear(
#           (_mlp): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (_mixprop_conv2): MixProp(
#         (_mlp): Linear(
#           (_mlp): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (_normalization): LayerNormalization()
#     )
#     (2): MTGNNLayer(
#       (_filter_conv): DilatedInception(
#         (_time_conv): ModuleList(
#           (0): Conv2d(32, 8, kernel_size=(1, 2), stride=(1, 1))
#           (1): Conv2d(32, 8, kernel_size=(1, 3), stride=(1, 1))
#           (2): Conv2d(32, 8, kernel_size=(1, 6), stride=(1, 1))
#           (3): Conv2d(32, 8, kernel_size=(1, 7), stride=(1, 1))
#         )
#       )
#       (_gate_conv): DilatedInception(
#         (_time_conv): ModuleList(
#           (0): Conv2d(32, 8, kernel_size=(1, 2), stride=(1, 1))
#           (1): Conv2d(32, 8, kernel_size=(1, 3), stride=(1, 1))
#           (2): Conv2d(32, 8, kernel_size=(1, 6), stride=(1, 1))
#           (3): Conv2d(32, 8, kernel_size=(1, 7), stride=(1, 1))
#         )
#       )
#       (_residual_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (_skip_conv): Conv2d(32, 64, kernel_size=(1, 82), stride=(1, 1))
#       (_mixprop_conv1): MixProp(
#         (_mlp): Linear(
#           (_mlp): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (_mixprop_conv2): MixProp(
#         (_mlp): Linear(
#           (_mlp): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (_normalization): LayerNormalization()
#     )
#   )
#   (_graph_constructor): GraphConstructor(
#     (_embedding1): Embedding(3, 1)
#     (_embedding2): Embedding(3, 1)
#     (_linear1): Linear(in_features=1, out_features=1, bias=True)
#     (_linear2): Linear(in_features=1, out_features=1, bias=True)
#   )
#   (_start_conv): Conv2d(1, 32, kernel_size=(1, 1), stride=(1, 1))
#   (_skip_conv_0): Conv2d(1, 64, kernel_size=(1, 100), stride=(1, 1))
#   (_skip_conv_E): Conv2d(32, 64, kernel_size=(1, 82), stride=(1, 1))
#   (_end_conv_1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#   (_end_conv_2): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
# Train Param
criterion = nn.MSELoss(size_average=False)
evaluateL2 = nn.MSELoss(size_average=False)
evaluateL1 = nn.L1Loss(size_average=False)
optimizer = torch.optim.Adam(model.parameters(),lr=0.01
11309868097305298, 0.10770413279533386, 0.12868979573249817, 0.10335489362478256, 0.10964034497737885, 0.14766892790794373, 0.0779971033334732, 0.13516584038734436, 0.09988106042146683, 0.14445070922374725, 0.12007886171340942, 0.1014704555273056, 0.11467190831899643, 0.14743264019489288, 0.08608852326869965, 0.13189184665679932, 0.09358631819486618, 0.10518977046012878, 0.08873827010393143, 0.09839385002851486, 0.1022629514336586, 0.09788192808628082, 0.11322186142206192, 0.04546511173248291, 0.10353820025920868, 0.06526701897382736, 0.1245763897895813, 0.08538874983787537, 0.12296951562166214, 0.07846678793430328, 0.13526368141174316, 0.06607967615127563, 0.14453169703483582, 0.11533129215240479, 0.11042630672454834, 0.16200865805149078, 0.07347798347473145, 0.10433301329612732, 0.06792078167200089, 0.0946313887834549, 0.08816762268543243, 0.11712506413459778, 0.10244126617908478, 0.0724778100848198, 0.10901571810245514, 0.06962020695209503, 0.1016446053981781, 0.08551245927810669, 0.07807990908622742, 0.10084603726863861, 0.07660329341888428, 0.10100798308849335, 0.15408119559288025, 0.09359048306941986, 0.0667693018913269, 0.09192672371864319, 0.08797207474708557, 0.07419297844171524, 0.06966179609298706, 0.08049269020557404, 0.0724388137459755, 0.05056478828191757, 0.11082518100738525, 0.0627652108669281, 0.06514949351549149, 0.04916013777256012, 0.08766491711139679, 0.05997016653418541, 0.06793142855167389, 0.09106232225894928, 0.12112148106098175, 0.07955335825681686, 0.06312824785709381, 0.08925211429595947, 0.07033931463956833, 0.07699938118457794, 0.05627305060625076, 0 ...

# %%
len(losses)
# Out:
# 7495

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(losses)
plt.yscale('log')
plt.grid()
plt.xlabel("Batch Number")
plt.ylabel("Mean Squared Error of Prediction")
plt.title("Error Over Epoch 1")
plt.show()

# %%
adj = model._graph_constructor(model._idx.to(device)).detach().cpu().numpy()
print(adj)
# Out:
# [[ 0.          0.          0.        ]
#  [ 0.94976944  0.          0.9767731 ]
#  [ 0.99670917  0.          0.        ]]

# %%
# Eval Loop
test_loader = DataLoader(obj,batch_size=40,shuffle=False)
loss_eval = list()
op_eval = list()
model.eval()
for e in tqdm(range(epochs)):
    for bid, samp in tqdm(enumerate(test_loader)):
#        if bid == 1:
#           break
        x = samp[0]
        # cuda stuff goes here
        op = model(x.float())
        op_eval.append(op.detach().cpu())
        y = torch.unsqueeze(samp[1],3) # or squeeze op
        loss = criterion(op,y.float())
        loss_eval.append(loss.item())
        del loss
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
type(adj)
# Out:
# numpy.ndarray

# %%
from est_lib.util.obspy_plot import adj_plot
adj_plot(
    min_lat=47.8,
    max_lat=52.,
    min_lon=-130.5,
    max_lon=-121,
    streams=obj.stream,
    inventory=obj.inv,
    adj_mat=adj)
